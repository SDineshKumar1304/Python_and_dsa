# %% [markdown]
# # Python and DSA November 23 - December 15
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # java compilation
#
# ![image.png](attachment:image.png)
#
# # Python Compilation
# ![image-3.png](attachment:image-3.png)

# %%
'''
What is Python?
How python works?
variables
data types
'''

# %%
a = 10
print(a)
type(a)
# Out:
# 10
# int

# %%
a = 10.5
print(a)
type(a)
# Out:
# 10.5
# float

# %%
a = "Python"
print(a)
type(a)
# Out:
# Python
# str

# %%
a = True
print(a)
type(a)
# Out:
# True
# bool

# %%
a = b"python"

# %%
print(a)
type(a)
# Out:
# b'python'
# bytes

# %%
a = 5+6j
print(a)
print(a.real)
print(a.imag)
type(a)
# Out:
# (5+6j)
# 5.0
# 6.0
# complex

# %%
a = {
    1:"Jayakaran",
    2:"Chantilyan"
}

print(a)
type(a)
# Out:
# {1: 'Jayakaran', 2: 'Chantilyan'}
# dict

# %%
t= ()
print(t)
type(t)
# Out:
# ()
# tuple

# %%
a = {1,1,1,3}
print(a)
type(a)
# Out:
# {1, 3}
# set

# %%
# list

a = [1,"python",1.3]
    #0  1   2
print(a)
type(a)

a[0] = "Dinesh"
print(a) # Mutable
# Out:
# [1, 'python', 1.3]
# ['Dinesh', 'python', 1.3]

# %%
# Tuple 

a = (1,"Dinesh",2.1)
print(a)
type(a)

print(a[0])# immuatble
# Out:
# (1, 'Dinesh', 2.1)
# 1

# %%
a = {"dinesh",2.2,1}
print(a)
type(a)
# Out:
# {1, 2.2, 'dinesh'}
# set

# %%
# dyanamic Input

# %%
a = int(input())
# Out:
# 5

# %%
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float(input())
# Out:
# 5

# %%
print(a)
type(a)
# Out:
# 5.0
# float

# %%
a = str(input())
print(a)
type(a)
# Out:
# python
# python
# str

# %%
a =input().encode()
# Out:
# python

# %%
print(a)
type(a)
# Out:
# b'python'
# bytes

# %%
# list or Array

# list
a = input().split(",")
print(a)
type(a)
# Out:
# 1.3,32,2
# ['1.3', '32', '2']
# list

# %%
# array
# integer array
a = list(map(int,input().split()))
# Out:
# 1 2 2 4 4

# %%
print(a)
type(a[0])
# Out:
# [1, 2, 2, 4, 4]
# int

# %%
# tuple
a = tuple(input().split())
# Out:
# 1 4 2 2

# %%
print(a)
type(a)
# Out:
# ('1', '4', '2', '2')
# tuple

# %%
# set
a = set(map(int,input().split(",")))  # remove Duplicate
print(sorted(a))
# Out:
# 1 1 1 3 2 4 2
# [1, 2, 3, 4]

# %%
# Dictionary 

monish = {  
    # {Keys : Values} = items 
    1:"Jayakaran",
    2:"Chantilyan"
}

print(monish.values())
print(monish.keys())
print(monish.items())
# Out:
# dict_values(['Jayakaran', 'Chantilyan'])
# dict_keys([1, 2])
# dict_items([(1, 'Jayakaran'), (2, 'Chantilyan')])

# %%
k = list(map(int,input().split()))
v = input().split()

d = dict(zip(k,v))
print(d)
print(d.keys())
print(d.values())
# Out:
# 1 2
# Dinesh chandu
# {1: 'Dinesh', 2: 'chandu'}
# dict_keys([1, 2])
# dict_values(['Dinesh', 'chandu'])

# %%
print(d.items())
# Out:
# dict_items([(1, 'Dinesh'), (2, 'chandu')])

# %%
print(4/2)# 2.0
print(4//2)# 2
# Out:
# 2.0
# 2

# %%
# Today Leetcode
# 1.https://leetcode.com/problems/score-of-a-string/description/

s = "hello"
t = 0

print(s[0],ord(s[0]))

print(s[0],s[1] ,":", ord(s[0]),ord(s[1]))

print("*********************************")

for i in range(len(s)-1):
    print(t,":",abs(ord(s[i])-ord(s[i+1])))
    t+=abs(ord(s[i])-ord(s[i+1]))
print(t)

# %%
# Night Leetcode Problems

# 2.https://leetcode.com/problems/final-value-of-variable-after-performing-operations/
# 3.https://leetcode.com/problems/defanging-an-ip-address/description/
# 4.https://leetcode.com/problems/jewels-and-stones/
# and more

# %%
# Day 2

# %%
# Loops and functions
# leetcode

# %%
# Day 3

# %%
# Functions and OOPs
# Leetcode

# %%
# Python Completed 
''' You guys now good is python'''

# %%
# Starting DSA

# Sorting
# Searching
# Stack
# Queue
# Linked List
#
